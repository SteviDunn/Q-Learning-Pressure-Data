# %% [markdown]
# <a href="https://colab.research.google.com/github/SteviDunn/Q-Learning-Pressure-Data/blob/main/AOA_3D_Matrix__N_Iteration_Dunn_Copy_of_Notebook_for_Topic_08_Video_Q_Learning_A_Complete_Example_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Scenario - Robots in a Warehouse
# A growing e-commerce company is building a new warehouse, and the company would like all of the picking operations in the new warehouse to be performed by warehouse robots.
# * In the context of e-commerce warehousing, “picking” is the task of gathering individual items from various locations in the warehouse in order to fulfill customer orders.
#
# After picking items from the shelves, the robots must bring the items to a specific location within the warehouse where the items can be packaged for shipping.
#
# In order to ensure maximum efficiency and productivity, the robots will need to learn the shortest path between the item packaging area and all other locations within the warehouse where the robots are allowed to travel.
# * We will use Q-learning to accomplish this task!
#
# #### Import Required Libraries

# %%
#import libraries
import numpy as np

# %% [markdown]
# ## Define the Environment
# The environment consists of **states**, **actions**, and **rewards**. States and actions are inputs for the Q-learning AI agent, while the possible actions are the AI agent's outputs.
# #### States
# The states in the environment are all of the possible locations within the warehouse. Some of these locations are for storing items (**black squares**), while other locations are aisles that the robot can use to travel throughout the warehouse (**white squares**). The **green square** indicates the item packaging and shipping area.
#
# The black and green squares are **terminal states**!
#
# ![warehouse map](https://www.danielsoper.com/teaching/img/08-warehouse-map.png)
#
# The AI agent's goal is to learn the shortest path between the item packaging area and all of the other locations in the warehouse where the robot is allowed to travel.
#
# As shown in the image above, there are 121 possible states (locations) within the warehouse. These states are arranged in a grid containing 11 rows and 11 columns. Each location can hence be identified by its row and column index.

# %%
# Define the shape of the 4D environment (i.e., its states)
environment_x = 4  # Number of rows (vertical axis)
environment_y = 8  # Number of columns (horizontal axis)
environment_z = 3  # Number of layers (depth)
environment_aoa = 3  # Number of angle of attack levels

# Define the number of possible actions (assuming 7 possible actions, e.g., move in 6 directions plus AOA change)
num_actions = 7

# Create a 5D numpy array to hold the Q-values for each state-action pair: Q(s, a)
# The array now contains 'environment_x', 'environment_y', 'environment_z', and 'environment_aoa'
# to match the 4D shape of the environment, plus the action dimension for Q-values.
q_values = np.zeros((environment_x, environment_y, environment_z, environment_aoa, num_actions))

# The q_values array is now a 5D array with dimensions (4, 8, 3, 3, 7),
# representing the 4D state space (including AOA) and the action space.

# %% [markdown]
# #### Actions
# The actions that are available to the AI agent are to move the robot in one of four directions:
# * Up
# * Right
# * Down
# * Left
#
# Obviously, the AI agent must learn to avoid driving into the item storage locations (e.g., shelves)!

# %%
# Define actions
# Numeric action codes:
# 0 = move up z, 1 = move down z, 2 = move right x, 3 = move left x,
# 4 = move forward y, 5 = move backward y, 6 = stay,
# 7 = increase AOA, 8 = decrease AOA
actions = [
    'up_z', 'down_z', 'right_x', 'left_x',
    'forward_y', 'backward_y', 'stay',
    'increase_aoa', 'decrease_aoa'
]

# Now, there are 9 possible actions, accounting for the new AOA dimension.
num_actions = len(actions)  # This will be 9

# %% [markdown]
# #### Rewards
# The last component of the environment that we need to define are the **rewards**.
#
# To help the AI agent learn, each state (location) in the warehouse is assigned a reward value.
#
# The agent may begin at any white square, but its goal is always the same: ***to maximize its total rewards***!
#
# Negative rewards (i.e., **punishments**) are used for all states except the goal.
# * This encourages the AI to identify the *shortest path* to the goal by *minimizing its punishments*!
#
# ![warehouse map](https://www.danielsoper.com/teaching/img/08-warehouse-map-rewards.png)
#
# To maximize its cumulative rewards (by minimizing its cumulative punishments), the AI agent will need find the shortest paths between the item packaging area (green square) and all of the other locations in the warehouse where the robot is allowed to travel (white squares). The agent will also need to learn to avoid crashing into any of the item storage locations (black squares)!

# %%
import numpy as np
##Data taken from L/D true stats 0 (not 1)
# Re-initializing the original matrix (3x4x8) and the two additional matrices for different AOAs
ld_ratios_aoa1 = np.array([
    [
        [-0.560847533, -0.549910806, -0.274771177, 0.17906459, 0.508083076, 0.479364257, 0.631179823, 0.544423392],
        [-1.896456314, -1.128275428, -0.379404476, 0.343553674, 1.196006183, 0.69787821, 0.56373206, 0.592049292],
        [-0.672843077, -0.522756134, 0.112989564, 0.660673904, 0.906478581, 0.87273689, 0.840761812, 0.811992305],
        [-0.280506088, 0.041536102, 0.703439779, 0.829640412, 0.94494181, 0.956008818, 0.831228384, 0.784962628]
    ],
    [
        [-0.073252714, -0.024258678, 0.391823059, 0.717513434, 0.913279534, 0.898604341, 0.856517598, 0.848944202],
        [-1.230233893, -0.472085117, 0.256742042, 0.879774892, 1.537068472, 1.015542931, 0.933517792, 0.862737841],
        [-0.482303262, -0.387791443, 0.399816267, 0.914603997, 1.103226727, 1.026804074, 0.904824902, 0.861630871],
        [-0.133467972, -0.149268045, 0.37746769, 0.633622619, 0.765301144, 0.68454384, 0.681714189, 0.590227279]
    ],
    [
        [1.68008597, 2.014682889, 1.979787083, 4.06447641, 5.058449713, 4.855977718, 4.769882173, 4.701115418],
        [-0.26305801, 1.079966811, 3.261120016, 5.427790842, 7.714367372, 5.238375795, 5.16754281, 4.82601987],
        [0.679493776, 1.727854201, 2.708559173, 5.014285095, 5.613175464, 5.192517442, 5.140730408, 4.778637736],
        [2.126749894, 2.128782325, 3.435657384, 4.349849545, 4.211052237, 4.532229962, 4.341667419, 4.280858792]
    ]
])

ld_ratios_aoa2 = np.array([
    [
        [-0.85379, -0.84453, -0.56022, -0.06628, 0.37986, 0.41998, 0.41249, 0.4571],
        [-1.87015, -1.20318, -0.26315, 0.39479, 1.53792, 0.58283, 0.48226, 0.43149],
        [-0.75481, -0.9494, 0.13764, 0.59038, 0.9183, 0.80119, 0.62282, 0.54975],
        [-0.61532, -0.42584, -0.06139, 0.36071, 0.65771, 0.65834, 0.60638, 0.50963]
    ],
    [
        [-0.68866, -0.74915, -0.47427, 0.05647, 0.46502, 0.40518, 0.32778, 0.32082],
        [-1.61831, -0.86785, 0.18366, 0.47784, 1.417, 0.66128, 0.48675, 0.32428],
        [-0.82634, -0.51604, 0.14678, 0.41475, 0.77826, 0.57504, 0.45781, 0.35237],
        [-0.53136, -0.5462, -0.32186, 0.28728, 0.48974, 0.43762, 0.41432, 0.32416]
    ],
    [
        [1.62563, 1.47, 1.68325, 2.86456, 4.24603, 4.21611, 4.33648, 4.35567],
        [-0.07066, 1.10294, 3.67149, 5.63637, 9.06201, 5.33921, 4.6232, 4.58389],
        [1.09722, 2.03986, 2.77107, 4.52965, 5.68317, 5.35768, 4.73271, 4.28755],
        [2.58787, 3.55767, 4.26496, 4.42522, 4.75202, 4.9988, 4.65062, 4.34528]
    ]
])

ld_ratios_aoa3 = np.array([
    [
        [-0.2419, -0.15264, 0.00376, 0.56413, -0.40147, -0.42427, -0.44084, 0.77374],
        [-1.27657, -0.74033, 0.04363, -0.73607, -0.02309, -0.36898, -0.46431, -0.49032],
        [-0.15158, -0.30351, 0.08621, 0.6776, -0.36884, 0.53997, 0.8615, 0.86059],
        [-0.06312, -0.01893, 0.52361, 0.77201, 0.89356, 0.84575, 0.86792, 0.79792]
    ],
    [
        [-0.04231, -0.07856, -0.00763, 0.49826, -0.47588, -0.46418, 0.71219, -0.51256],
        [-0.83529, -0.60825, -0.13244, -0.78788, -0.17724, -0.41714, -0.49839, 0.23287],
        [-0.23809, -0.29614, -0.08143, 0.44881, -0.44097, -0.43293, 0.61755, -0.53545],
        [-0.07924, -0.15566, 0.17938, 0.4737, 0.65039, 0.6634, -0.54116, -0.53267]
    ],
    [
        [1.88072, 1.86878, 2.81673, 3.58065, 4.34279, 4.1078, 3.00279, 4.28956],
        [0.61285, 1.37992, 2.8145, 3.98211, 7.11544, 4.99674, 4.46355, 4.2167],
        [1.48737, 2.55674, 2.93813, 0.94013, 1.15169, 1.0747, 1.0509, 4.09221],
        [2.8802, 3.38346, 3.58961, 4.43283, 1.31512, 5.05872, 5.00518, 4.6079]
    ]
])

# Combining the matrices along a new dimension for AOA
rewards = np.stack([ld_ratios_aoa1, ld_ratios_aoa2, ld_ratios_aoa3], axis=3)
max_reward = np.max(rewards)

# Confirming the shape of the resulting matrix
rewards.shape
print(f"Largest Reward: {max_reward}")
# Out:
# Largest Reward: 9.06201

# %% [markdown]
# ## Train the Model
# Our next task is for our AI agent to learn about its environment by implementing a Q-learning model. The learning process will follow these steps:
# 1. Choose a random, non-terminal state (white square) for the agent to begin this new episode.
# 2. Choose an action (move *up*, *right*, *down*, or *left*) for the current state. Actions will be chosen using an *epsilon greedy algorithm*. This algorithm will usually choose the most promising action for the AI agent, but it will occasionally choose a less promising option in order to encourage the agent to explore the environment.
# 3. Perform the chosen action, and transition to the next state (i.e., move to the next location).
# 4. Receive the reward for moving to the new state, and calculate the temporal difference.
# 5. Update the Q-value for the previous state and action pair.
# 6. If the new (current) state is a terminal state, go to #1. Else, go to #2.
#
# This entire process will be repeated across 1000 episodes. This will provide the AI agent sufficient opportunity to learn the shortest paths between the item packaging area and all other locations in the warehouse where the robot is allowed to travel, while simultaneously avoiding crashing into any of the item storage locations!
#
# #### Define Helper Functions

# %%
# Get starting location at random in 4D space
def get_starting_location():
    # Get a random x, y, z, and AOA index
    current_x_index = np.random.randint(environment_x)
    current_y_index = np.random.randint(environment_y)
    current_z_index = np.random.randint(environment_z)
    current_aoa_index = np.random.randint(environment_aoa)
    return current_x_index, current_y_index, current_z_index, current_aoa_index

# Define an epsilon greedy algorithm that will choose which action to take next
def get_next_action(current_x_index, current_y_index, current_z_index, current_aoa_index, epsilon):
    # If a randomly chosen value between 0 and 1 is less than epsilon,
    # then choose the most promising value from the Q-table for this state.
    if np.random.random() < epsilon:
        # Choose the action with the highest Q-value for the current state
        return np.argmax(q_values[current_x_index, current_y_index, current_z_index, current_aoa_index])
    else:
        # Choose a random action from the available action space
        return np.random.randint(num_actions)  # Use the total number of actions (9)


# Define a function that will get the next location based on the chosen action
def get_next_location(current_x_index, current_y_index, current_z_index, current_aoa_index, action_index):
    new_x_index = current_x_index
    new_y_index = current_y_index
    new_z_index = current_z_index
    new_aoa_index = current_aoa_index

    if actions[action_index] == 'up_z' and current_z_index > 0:
        new_z_index -= 1
    elif actions[action_index] == 'down_z' and current_z_index < environment_z - 1:
        new_z_index += 1
    elif actions[action_index] == 'right_x' and current_x_index < environment_x - 1:
        new_x_index += 1
    elif actions[action_index] == 'left_x' and current_x_index > 0:
        new_x_index -= 1
    elif actions[action_index] == 'forward_y' and current_y_index < environment_y - 1:
        new_y_index += 1
    elif actions[action_index] == 'backward_y' and current_y_index > 0:
        new_y_index -= 1
    elif actions[action_index] == 'increase_aoa' and current_aoa_index < environment_aoa - 1:
        new_aoa_index += 1
    elif actions[action_index] == 'decrease_aoa' and current_aoa_index > 0:
        new_aoa_index -= 1
    elif actions[action_index] == 'stay':
        pass  # No movement if the action is 'stay'

    return new_x_index, new_y_index, new_z_index, new_aoa_index

# %%
#define helper functions for the termination condition after convergence of steps

# Initialize Q-table with zeros for 4D environment
def initialize_q_table(environment_x, environment_y, environment_z, environment_aoa, num_actions=9):
    return np.zeros((environment_x, environment_y, environment_z, environment_aoa, num_actions))

# Q-learning update function with temporal difference for 4D state space
def q_learning_update(q_values, state, action, reward, next_state, learning_rate, discount_factor):
    old_q_value = q_values[state[0], state[1], state[2], state[3], action]

    # Calculate the temporal difference (TD error)
    future_reward = np.max(q_values[next_state[0], next_state[1], next_state[2], next_state[3]])  # Max reward for the next state
    temporal_difference = reward + discount_factor * future_reward - old_q_value

    # Update the Q-value with the TD error
    new_q_value = old_q_value + learning_rate * temporal_difference

    # Update the Q-value in the Q-table
    q_values[state[0], state[1], state[2], state[3], action] = new_q_value

    # Return the absolute difference between old and new Q-values for convergence tracking
    return abs(new_q_value - old_q_value)


# Print the converged results helper function for 4D state space
def print_converged_results(q_values, rewards):
    # Find the maximum Q-value
    max_q_value = np.max(q_values)

    # Find the state-action pair corresponding to the highest Q-value
    max_q_value_location = np.unravel_index(np.argmax(q_values), q_values.shape)
    max_state = max_q_value_location[:4]  # extract the (x, y, z, aoa) state
    max_action = max_q_value_location[4]  # extract the action

    # Get the L/D ratio from the rewards grid (only x, y, z, aoa needed for rewards)
    max_ld_ratio = rewards[max_state[0], max_state[1], max_state[2], max_state[3]]

    # Print the highest Q-value and corresponding L/D ratio
    print(f"\nHighest Q-value (indicating best state for L/D ratio): {max_q_value}")
    print(f"Location (State): {max_state}, Action: {max_action}")
    print(f"Highest L/D Ratio at this location: {max_ld_ratio}")


# Convergence function for 4D state space
def check_convergence(q_value_diff_sum, convergence_threshold, q_values, rewards):
    if q_value_diff_sum < convergence_threshold:
        print("Convergence Achieved!")
        print(f"Q-value Difference Sum: {q_value_diff_sum}")
        print_converged_results(q_values, rewards)


# Find the highest L/D ratio in the rewards grid for 4D environment
def find_highest_ld_ratio(rewards):
    # Find the highest L/D ratio in the rewards grid
    max_ld_ratio = np.max(rewards)
    max_ld_location = np.unravel_index(np.argmax(rewards), rewards.shape)

    # Print the highest L/D ratio and its location
    print(f"Highest L/D Ratio: {max_ld_ratio} at Location: {max_ld_location}")

    return max_ld_ratio, max_ld_location

def extract_policy(q_values):
    # The policy maps each state (x, y, z, aoa) to the best action based on the Q-values
    policy = np.argmax(q_values, axis=4)  # Find the action with the highest Q-value for each state
    return policy

# %% [markdown]
# #### Train the AI Agent using Q-Learning

# %%
# Update training parameters
epsilon = 0.70  # the percentage of time when we should take the best action (instead of a random action)
learning_rate = 0.7  # the rate at which the AI agent should learn
discount_factor = 0.9  # discount factor for future rewards

n_iterations = 10000  # the number of times that we'll run the training
num_steps = 100

# Q-value helper function call
q_values = initialize_q_table(environment_x, environment_y, environment_z, environment_aoa)  # Initialize Q-table for 4D space

# Run through 10000 training episodes
for episode in range(n_iterations):
    # Get the starting location for this episode in 4D space
    x_index, y_index, z_index, aoa_index = get_starting_location()

    # Print the starting location to verify it's different each time
    print(f"Episode {episode + 1}: Starting Location - X: {x_index}, Y: {y_index}, Z: {z_index}, AOA: {aoa_index}")

    q_value_diff_sum = 0  # Track the total Q-value convergence for training

    for step in range(num_steps):
        # Choose which action to take using epsilon-greedy
        action_index = get_next_action(x_index, y_index, z_index, aoa_index, epsilon)

        # Perform the action and transition to the next state
        old_x_index, old_y_index, old_z_index, old_aoa_index = x_index, y_index, z_index, aoa_index
        x_index, y_index, z_index, aoa_index = get_next_location(x_index, y_index, z_index, aoa_index, action_index)

        # Receive the reward for moving to the new state (reward grid is in 4D space)
        reward = rewards[z_index, x_index, y_index, aoa_index] - 7.7

        # Perform Q-learning update with helper function
        q_value_diff = q_learning_update(q_values,
                                         (old_x_index, old_y_index, old_z_index, old_aoa_index),
                                         action_index,
                                         reward,
                                         (x_index, y_index, z_index, aoa_index),
                                         learning_rate,
                                         discount_factor)

        # Accumulate the absolute difference for convergence tracking
        q_value_diff_sum += q_value_diff

    # Optionally, check for convergence here after each episode if needed
    if episode % 1000 == 0:  # Print convergence info every 1000 episodes
        print(f"After {episode + 1} episodes, Q-value difference sum: {q_value_diff_sum}")

# Call the function to find the highest L/D ratio in the rewards grid
max_ld_ratio, max_ld_location = find_highest_ld_ratio(rewards)

# Optional: Print a summary of your Q-learning results if needed
#print_converged_results(q_values, rewards)

print()

#extract the policy
policy = extract_policy(q_values)

# Training is complete
print('Training Complete')

# Print the whole Q-value table
# print("Q-values after training:")
# print(q_values)
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 5008: Starting Location - X: 1, Y: 1, Z: 0, AOA: 1
# Episode 5009: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 5010: Starting Location - X: 1, Y: 3, Z: 0, AOA: 1
# Episode 5011: Starting Location - X: 2, Y: 7, Z: 2, AOA: 0
# Episode 5012: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 5013: Starting Location - X: 1, Y: 4, Z: 0, AOA: 1
# Episode 5014: Starting Location - X: 2, Y: 6, Z: 1, AOA: 2
# Episode 5015: Starting Location - X: 1, Y: 2, Z: 2, AOA: 1
# Episode 5016: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5017: Starting Location - X: 1, Y: 4, Z: 1, AOA: 1
# Episode 5018: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5019: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 5020: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5021: Starting Location - X: 2, Y: 1, Z: 0, AOA: 0
# Episode 5022: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 5023: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 5024: Starting Location - X: 0, Y: 0, Z: 2, AOA: 0
# Episode 5025: Starting Location - X: 0, Y: 6, Z: 2, AOA: 1
# Episode 5026: Starting Location - X: 2, Y: 0, Z: 1, AOA: 2
# Episode 5027: Starting Location - X: 0, Y: 1, Z: 1, AOA: 2
# Episode 5028: Starting Location - X: 3, Y: 5, Z: 2, AOA: 2
# Episode 5029: Starting Location - X: 3, Y: 3, Z: 2, AOA: 2
# Episode 5030: Starting Location - X: 2, Y: 1, Z: 0, AOA: 2
# Episode 5031: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5032: Starting Location - X: 1, Y: 6, Z: 0, AOA: 1
# Episode 5033: Starting Location - X: 3, Y: 3, Z: 0, AOA: 0
# Episode 5034: Starting Location - X: 3, Y: 5, Z: 2, AOA: 0
# Episode 5035: Starting Location - X: 0, Y: 6, Z: 0, AOA: 0
# Episode 5036: Starting Location - X: 1, Y: 5, Z: 2, AOA: 0
# Episode 5037: Starting Location - X: 1, Y: 3, Z: 1, AOA: 0
# Episode 5038: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 5039: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 5040: Starting Location - X: 2, Y: 0, Z: 0, AOA: 0
# Episode 5041: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 5042: Starting Location - X: 0, Y: 2, Z: 0, AOA: 2
# Episode 5043: Starting Location - X: 1, Y: 0, Z: 0, AOA: 0
# Episode 5044: Starting Location - X: 3, Y: 1, Z: 1, AOA: 1
# Episode 5045: Starting Location - X: 2, Y: 6, Z: 0, AOA: 1
# Episode 5046: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 5047: Starting Location - X: 1, Y: 7, Z: 0, AOA: 0
# Episode 5048: Starting Location - X: 2, Y: 5, Z: 2, AOA: 2
# Episode 5049: Starting Location - X: 1, Y: 1, Z: 1, AOA: 0
# Episode 5050: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5051: Starting Location - X: 3, Y: 6, Z: 2, AOA: 0
# Episode 5052: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 5053: Starting Location - X: 0, Y: 1, Z: 1, AOA: 0
# Episode 5054: Starting Location - X: 1, Y: 4, Z: 2, AOA: 2
# Episode 5055: Starting Location - X: 1, Y: 3, Z: 0, AOA: 0
# Episode 5056: Starting Location - X: 3, Y: 1, Z: 2, AOA: 0
# Episode 5057: Starting Location - X: 0, Y: 3, Z: 2, AOA: 0
# Episode 5058: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 5059: Starting Location - X: 1, Y: 1, Z: 2, AOA: 0
# Episode 5060: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 5061: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5062: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 5063: Starting Location - X: 0, Y: 7, Z: 0, AOA: 0
# Episode 5064: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5065: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 5066: Starting Location - X: 0, Y: 7, Z: 2, AOA: 0
# Episode 5067: Starting Location - X: 1, Y: 2, Z: 0, AOA: 2
# Episode 5068: Starting Location - X: 3, Y: 7, Z: 1, AOA: 1
# Episode 5069: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 5070: Starting Location - X: 1, Y: 0, Z: 0, AOA: 1
# Episode 5071: Starting Location - X: 1, Y: 5, Z: 2, AOA: 2
# Episode 5072: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5073: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5074: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5075: Starting Location - X: 0, Y: 3, Z: 1, AOA: 1
# Episode 5076: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5077: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 5078: Starting Location - X: 1, Y: 3, Z: 2, AOA: 0
# Episode 5079: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 5080: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 5081: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5082: Starting Location - X: 0, Y: 2, Z: 0, AOA: 1
# Episode 5083: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 5084: Starting Location - X: 1, Y: 5, Z: 2, AOA: 2
# Episode 5085: Starting Location - X: 3, Y: 5, Z: 0, AOA: 1
# Episode 5086: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 5087: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 5088: Starting Location - X: 2, Y: 2, Z: 0, AOA: 0
# Episode 5089: Starting Location - X: 0, Y: 1, Z: 1, AOA: 0
# Episode 5090: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5091: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5092: Starting Location - X: 3, Y: 0, Z: 0, AOA: 2
# Episode 5093: Starting Location - X: 1, Y: 5, Z: 0, AOA: 0
# Episode 5094: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 5095: Starting Location - X: 0, Y: 2, Z: 0, AOA: 1
# Episode 5096: Starting Location - X: 3, Y: 7, Z: 2, AOA: 0
# Episode 5097: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 5098: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5099: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5100: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5101: Starting Location - X: 0, Y: 3, Z: 0, AOA: 0
# Episode 5102: Starting Location - X: 0, Y: 1, Z: 2, AOA: 2
# Episode 5103: Starting Location - X: 2, Y: 6, Z: 0, AOA: 2
# Episode 5104: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 5105: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5106: Starting Location - X: 1, Y: 2, Z: 0, AOA: 0
# Episode 5107: Starting Location - X: 2, Y: 0, Z: 1, AOA: 0
# Episode 5108: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 5109: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5110: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5111: Starting Location - X: 1, Y: 0, Z: 1, AOA: 2
# Episode 5112: Starting Location - X: 3, Y: 3, Z: 2, AOA: 0
# Episode 5113: Starting Location - X: 1, Y: 2, Z: 2, AOA: 0
# Episode 5114: Starting Location - X: 0, Y: 5, Z: 0, AOA: 1
# Episode 5115: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5116: Starting Location - X: 1, Y: 4, Z: 0, AOA: 2
# Episode 5117: Starting Location - X: 1, Y: 6, Z: 1, AOA: 0
# Episode 5118: Starting Location - X: 3, Y: 4, Z: 2, AOA: 1
# Episode 5119: Starting Location - X: 0, Y: 1, Z: 2, AOA: 1
# Episode 5120: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 5121: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 5122: Starting Location - X: 0, Y: 4, Z: 2, AOA: 0
# Episode 5123: Starting Location - X: 0, Y: 7, Z: 1, AOA: 0
# Episode 5124: Starting Location - X: 3, Y: 5, Z: 2, AOA: 2
# Episode 5125: Starting Location - X: 1, Y: 3, Z: 2, AOA: 2
# Episode 5126: Starting Location - X: 2, Y: 1, Z: 0, AOA: 0
# Episode 5127: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 5128: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 5129: Starting Location - X: 3, Y: 2, Z: 2, AOA: 0
# Episode 5130: Starting Location - X: 2, Y: 0, Z: 2, AOA: 2
# Episode 5131: Starting Location - X: 1, Y: 0, Z: 2, AOA: 1
# Episode 5132: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Episode 5133: Starting Location - X: 2, Y: 6, Z: 0, AOA: 1
# Episode 5134: Starting Location - X: 3, Y: 6, Z: 0, AOA: 1
# Episode 5135: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5136: Starting Location - X: 1, Y: 3, Z: 0, AOA: 1
# Episode 5137: Starting Location - X: 3, Y: 6, Z: 2, AOA: 0
# Episode 5138: Starting Location - X: 1, Y: 1, Z: 2, AOA: 2
# Episode 5139: Starting Location - X: 3, Y: 4, Z: 1, AOA: 0
# Episode 5140: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 5141: Starting Location - X: 1, Y: 7, Z: 0, AOA: 2
# Episode 5142: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 5143: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 5144: Starting Location - X: 0, Y: 6, Z: 2, AOA: 2
# Episode 5145: Starting Location - X: 2, Y: 0, Z: 0, AOA: 2
# Episode 5146: Starting Location - X: 3, Y: 2, Z: 1, AOA: 2
# Episode 5147: Starting Location - X: 2, Y: 7, Z: 1, AOA: 0
# Episode 5148: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 5149: Starting Location - X: 1, Y: 3, Z: 1, AOA: 0
# Episode 5150: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5151: Starting Location - X: 1, Y: 4, Z: 0, AOA: 0
# Episode 5152: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5153: Starting Location - X: 2, Y: 3, Z: 2, AOA: 1
# Episode 5154: Starting Location - X: 3, Y: 6, Z: 1, AOA: 0
# Episode 5155: Starting Location - X: 0, Y: 6, Z: 0, AOA: 0
# Episode 5156: Starting Location - X: 2, Y: 7, Z: 0, AOA: 0
# Episode 5157: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5158: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5159: Starting Location - X: 1, Y: 6, Z: 2, AOA: 1
# Episode 5160: Starting Location - X: 1, Y: 4, Z: 1, AOA: 1
# Episode 5161: Starting Location - X: 0, Y: 1, Z: 1, AOA: 0
# Episode 5162: Starting Location - X: 0, Y: 2, Z: 2, AOA: 1
# Episode 5163: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 5164: Starting Location - X: 1, Y: 4, Z: 2, AOA: 0
# Episode 5165: Starting Location - X: 0, Y: 2, Z: 0, AOA: 2
# Episode 5166: Starting Location - X: 0, Y: 2, Z: 1, AOA: 0
# Episode 5167: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5168: Starting Location - X: 3, Y: 4, Z: 2, AOA: 1
# Episode 5169: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 5170: Starting Location - X: 0, Y: 0, Z: 1, AOA: 1
# Episode 5171: Starting Location - X: 0, Y: 7, Z: 1, AOA: 2
# Episode 5172: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 5173: Starting Location - X: 3, Y: 6, Z: 1, AOA: 2
# Episode 5174: Starting Location - X: 0, Y: 2, Z: 2, AOA: 1
# Episode 5175: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 5176: Starting Location - X: 2, Y: 2, Z: 0, AOA: 0
# Episode 5177: Starting Location - X: 0, Y: 7, Z: 0, AOA: 0
# Episode 5178: Starting Location - X: 0, Y: 6, Z: 1, AOA: 2
# Episode 5179: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 5180: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 5181: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5182: Starting Location - X: 2, Y: 0, Z: 2, AOA: 0
# Episode 5183: Starting Location - X: 2, Y: 4, Z: 1, AOA: 0
# Episode 5184: Starting Location - X: 3, Y: 3, Z: 0, AOA: 2
# Episode 5185: Starting Location - X: 2, Y: 4, Z: 0, AOA: 2
# Episode 5186: Starting Location - X: 3, Y: 2, Z: 0, AOA: 0
# Episode 5187: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 5188: Starting Location - X: 3, Y: 2, Z: 1, AOA: 0
# Episode 5189: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5190: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5191: Starting Location - X: 1, Y: 0, Z: 0, AOA: 0
# Episode 5192: Starting Location - X: 0, Y: 7, Z: 0, AOA: 0
# Episode 5193: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 5194: Starting Location - X: 2, Y: 1, Z: 0, AOA: 2
# Episode 5195: Starting Location - X: 1, Y: 1, Z: 1, AOA: 2
# Episode 5196: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 5197: Starting Location - X: 1, Y: 0, Z: 1, AOA: 2
# Episode 5198: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5199: Starting Location - X: 0, Y: 5, Z: 1, AOA: 0
# Episode 5200: Starting Location - X: 0, Y: 7, Z: 1, AOA: 2
# Episode 5201: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 5202: Starting Location - X: 1, Y: 3, Z: 0, AOA: 0
# Episode 5203: Starting Location - X: 0, Y: 4, Z: 0, AOA: 0
# Episode 5204: Starting Location - X: 1, Y: 1, Z: 0, AOA: 2
# Episode 5205: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 5206: Starting Location - X: 3, Y: 2, Z: 0, AOA: 1
# Episode 5207: Starting Location - X: 3, Y: 0, Z: 0, AOA: 1
# Episode 5208: Starting Location - X: 3, Y: 5, Z: 0, AOA: 0
# Episode 5209: Starting Location - X: 3, Y: 6, Z: 0, AOA: 2
# Episode 5210: Starting Location - X: 3, Y: 6, Z: 1, AOA: 1
# Episode 5211: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 5212: Starting Location - X: 0, Y: 7, Z: 2, AOA: 2
# Episode 5213: Starting Location - X: 1, Y: 0, Z: 2, AOA: 1
# Episode 5214: Starting Location - X: 3, Y: 6, Z: 1, AOA: 2
# Episode 5215: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 5216: Starting Location - X: 0, Y: 6, Z: 0, AOA: 0
# Episode 5217: Starting Location - X: 1, Y: 3, Z: 0, AOA: 1
# Episode 5218: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5219: Starting Location - X: 1, Y: 2, Z: 0, AOA: 1
# Episode 5220: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 5221: Starting Location - X: 2, Y: 2, Z: 2, AOA: 0
# Episode 5222: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 5223: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5224: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5225: Starting Location - X: 0, Y: 3, Z: 0, AOA: 0
# Episode 5226: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5227: Starting Location - X: 2, Y: 7, Z: 2, AOA: 2
# Episode 5228: Starting Location - X: 3, Y: 0, Z: 2, AOA: 2
# Episode 5229: Starting Location - X: 2, Y: 2, Z: 0, AOA: 2
# Episode 5230: Starting Location - X: 2, Y: 4, Z: 0, AOA: 1
# Episode 5231: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 5232: Starting Location - X: 2, Y: 4, Z: 1, AOA: 1
# Episode 5233: Starting Location - X: 0, Y: 1, Z: 0, AOA: 1
# Episode 5234: Starting Location - X: 3, Y: 6, Z: 2, AOA: 0
# Episode 5235: Starting Location - X: 1, Y: 3, Z: 1, AOA: 2
# Episode 5236: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 5237: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5238: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 5239: Starting Location - X: 1, Y: 3, Z: 1, AOA: 0
# Episode 5240: Starting Location - X: 1, Y: 0, Z: 2, AOA: 0
# Episode 5241: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 5242: Starting Location - X: 0, Y: 5, Z: 0, AOA: 1
# Episode 5243: Starting Location - X: 0, Y: 3, Z: 2, AOA: 1
# Episode 5244: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 5245: Starting Location - X: 0, Y: 0, Z: 2, AOA: 2
# Episode 5246: Starting Location - X: 2, Y: 1, Z: 0, AOA: 0
# Episode 5247: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5248: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 5249: Starting Location - X: 3, Y: 5, Z: 2, AOA: 1
# Episode 5250: Starting Location - X: 2, Y: 7, Z: 0, AOA: 2
# Episode 5251: Starting Location - X: 1, Y: 4, Z: 0, AOA: 1
# Episode 5252: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 5253: Starting Location - X: 1, Y: 7, Z: 0, AOA: 0
# Episode 5254: Starting Location - X: 1, Y: 5, Z: 1, AOA: 1
# Episode 5255: Starting Location - X: 2, Y: 6, Z: 2, AOA: 1
# Episode 5256: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 5257: Starting Location - X: 2, Y: 5, Z: 2, AOA: 2
# Episode 5258: Starting Location - X: 1, Y: 5, Z: 1, AOA: 1
# Episode 5259: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 5260: Starting Location - X: 0, Y: 4, Z: 2, AOA: 2
# Episode 5261: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 5262: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 5263: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 5264: Starting Location - X: 3, Y: 4, Z: 1, AOA: 2
# Episode 5265: Starting Location - X: 3, Y: 5, Z: 0, AOA: 1
# Episode 5266: Starting Location - X: 2, Y: 2, Z: 0, AOA: 0
# Episode 5267: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 5268: Starting Location - X: 3, Y: 5, Z: 0, AOA: 0
# Episode 5269: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5270: Starting Location - X: 0, Y: 4, Z: 0, AOA: 0
# Episode 5271: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5272: Starting Location - X: 3, Y: 6, Z: 0, AOA: 2
# Episode 5273: Starting Location - X: 1, Y: 1, Z: 0, AOA: 2
# Episode 5274: Starting Location - X: 1, Y: 5, Z: 0, AOA: 1
# Episode 5275: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5276: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5277: Starting Location - X: 2, Y: 5, Z: 2, AOA: 2
# Episode 5278: Starting Location - X: 3, Y: 3, Z: 2, AOA: 0
# Episode 5279: Starting Location - X: 2, Y: 2, Z: 2, AOA: 2
# Episode 5280: Starting Location - X: 0, Y: 6, Z: 1, AOA: 0
# Episode 5281: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5282: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5283: Starting Location - X: 1, Y: 2, Z: 2, AOA: 0
# Episode 5284: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 5285: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5286: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 5287: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5288: Starting Location - X: 1, Y: 6, Z: 1, AOA: 0
# Episode 5289: Starting Location - X: 3, Y: 0, Z: 1, AOA: 1
# Episode 5290: Starting Location - X: 1, Y: 6, Z: 0, AOA: 2
# Episode 5291: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5292: Starting Location - X: 1, Y: 6, Z: 0, AOA: 0
# Episode 5293: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 5294: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 5295: Starting Location - X: 0, Y: 6, Z: 0, AOA: 1
# Episode 5296: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5297: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5298: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 5299: Starting Location - X: 1, Y: 0, Z: 0, AOA: 1
# Episode 5300: Starting Location - X: 2, Y: 1, Z: 2, AOA: 2
# Episode 5301: Starting Location - X: 0, Y: 7, Z: 1, AOA: 1
# Episode 5302: Starting Location - X: 1, Y: 2, Z: 2, AOA: 1
# Episode 5303: Starting Location - X: 1, Y: 3, Z: 2, AOA: 2
# Episode 5304: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 5305: Starting Location - X: 3, Y: 3, Z: 1, AOA: 1
# Episode 5306: Starting Location - X: 2, Y: 4, Z: 1, AOA: 1
# Episode 5307: Starting Location - X: 1, Y: 6, Z: 2, AOA: 1
# Episode 5308: Starting Location - X: 2, Y: 7, Z: 0, AOA: 1
# Episode 5309: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 5310: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 5311: Starting Location - X: 1, Y: 7, Z: 1, AOA: 0
# Episode 5312: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 5313: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 5314: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5315: Starting Location - X: 2, Y: 3, Z: 2, AOA: 0
# Episode 5316: Starting Location - X: 0, Y: 3, Z: 2, AOA: 1
# Episode 5317: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5318: Starting Location - X: 1, Y: 7, Z: 1, AOA: 2
# Episode 5319: Starting Location - X: 0, Y: 4, Z: 1, AOA: 0
# Episode 5320: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5321: Starting Location - X: 3, Y: 1, Z: 1, AOA: 1
# Episode 5322: Starting Location - X: 2, Y: 7, Z: 0, AOA: 1
# Episode 5323: Starting Location - X: 2, Y: 5, Z: 0, AOA: 0
# Episode 5324: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 5325: Starting Location - X: 2, Y: 2, Z: 2, AOA: 0
# Episode 5326: Starting Location - X: 2, Y: 0, Z: 2, AOA: 0
# Episode 5327: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 5328: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 5329: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5330: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5331: Starting Location - X: 2, Y: 2, Z: 1, AOA: 2
# Episode 5332: Starting Location - X: 3, Y: 5, Z: 2, AOA: 1
# Episode 5333: Starting Location - X: 1, Y: 1, Z: 0, AOA: 2
# Episode 5334: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5335: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 5336: Starting Location - X: 0, Y: 5, Z: 1, AOA: 1
# Episode 5337: Starting Location - X: 0, Y: 6, Z: 0, AOA: 0
# Episode 5338: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 5339: Starting Location - X: 2, Y: 6, Z: 2, AOA: 2
# Episode 5340: Starting Location - X: 3, Y: 3, Z: 2, AOA: 2
# Episode 5341: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5342: Starting Location - X: 2, Y: 7, Z: 2, AOA: 1
# Episode 5343: Starting Location - X: 3, Y: 2, Z: 0, AOA: 1
# Episode 5344: Starting Location - X: 3, Y: 2, Z: 2, AOA: 2
# Episode 5345: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5346: Starting Location - X: 3, Y: 6, Z: 0, AOA: 1
# Episode 5347: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5348: Starting Location - X: 0, Y: 7, Z: 1, AOA: 1
# Episode 5349: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5350: Starting Location - X: 0, Y: 1, Z: 0, AOA: 2
# Episode 5351: Starting Location - X: 3, Y: 4, Z: 1, AOA: 1
# Episode 5352: Starting Location - X: 3, Y: 1, Z: 1, AOA: 1
# Episode 5353: Starting Location - X: 2, Y: 4, Z: 0, AOA: 0
# Episode 5354: Starting Location - X: 3, Y: 5, Z: 0, AOA: 1
# Episode 5355: Starting Location - X: 0, Y: 3, Z: 2, AOA: 2
# Episode 5356: Starting Location - X: 1, Y: 7, Z: 1, AOA: 0
# Episode 5357: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5358: Starting Location - X: 2, Y: 4, Z: 0, AOA: 2
# Episode 5359: Starting Location - X: 2, Y: 4, Z: 0, AOA: 1
# Episode 5360: Starting Location - X: 2, Y: 1, Z: 1, AOA: 0
# Episode 5361: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5362: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5363: Starting Location - X: 3, Y: 4, Z: 1, AOA: 0
# Episode 5364: Starting Location - X: 1, Y: 5, Z: 0, AOA: 1
# Episode 5365: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 5366: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 5367: Starting Location - X: 1, Y: 5, Z: 2, AOA: 0
# Episode 5368: Starting Location - X: 3, Y: 6, Z: 0, AOA: 2
# Episode 5369: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5370: Starting Location - X: 3, Y: 7, Z: 0, AOA: 0
# Episode 5371: Starting Location - X: 1, Y: 4, Z: 1, AOA: 2
# Episode 5372: Starting Location - X: 1, Y: 4, Z: 2, AOA: 2
# Episode 5373: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 5374: Starting Location - X: 0, Y: 4, Z: 1, AOA: 0
# Episode 5375: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 5376: Starting Location - X: 3, Y: 6, Z: 2, AOA: 0
# Episode 5377: Starting Location - X: 0, Y: 6, Z: 2, AOA: 1
# Episode 5378: Starting Location - X: 0, Y: 6, Z: 0, AOA: 1
# Episode 5379: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5380: Starting Location - X: 1, Y: 0, Z: 0, AOA: 2
# Episode 5381: Starting Location - X: 0, Y: 0, Z: 0, AOA: 1
# Episode 5382: Starting Location - X: 0, Y: 7, Z: 2, AOA: 1
# Episode 5383: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5384: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 5385: Starting Location - X: 0, Y: 1, Z: 0, AOA: 2
# Episode 5386: Starting Location - X: 2, Y: 1, Z: 0, AOA: 2
# Episode 5387: Starting Location - X: 0, Y: 7, Z: 1, AOA: 1
# Episode 5388: Starting Location - X: 0, Y: 5, Z: 1, AOA: 1
# Episode 5389: Starting Location - X: 1, Y: 4, Z: 0, AOA: 0
# Episode 5390: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5391: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 5392: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 5393: Starting Location - X: 3, Y: 0, Z: 2, AOA: 1
# Episode 5394: Starting Location - X: 0, Y: 3, Z: 1, AOA: 0
# Episode 5395: Starting Location - X: 1, Y: 0, Z: 1, AOA: 2
# Episode 5396: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 5397: Starting Location - X: 1, Y: 4, Z: 2, AOA: 2
# Episode 5398: Starting Location - X: 3, Y: 4, Z: 0, AOA: 0
# Episode 5399: Starting Location - X: 3, Y: 3, Z: 0, AOA: 0
# Episode 5400: Starting Location - X: 0, Y: 6, Z: 0, AOA: 2
# Episode 5401: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5402: Starting Location - X: 2, Y: 2, Z: 0, AOA: 2
# Episode 5403: Starting Location - X: 1, Y: 0, Z: 1, AOA: 2
# Episode 5404: Starting Location - X: 3, Y: 6, Z: 1, AOA: 0
# Episode 5405: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5406: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 5407: Starting Location - X: 0, Y: 4, Z: 0, AOA: 0
# Episode 5408: Starting Location - X: 1, Y: 4, Z: 0, AOA: 1
# Episode 5409: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5410: Starting Location - X: 0, Y: 4, Z: 0, AOA: 2
# Episode 5411: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 5412: Starting Location - X: 0, Y: 0, Z: 0, AOA: 1
# Episode 5413: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 5414: Starting Location - X: 0, Y: 5, Z: 1, AOA: 1
# Episode 5415: Starting Location - X: 3, Y: 1, Z: 2, AOA: 2
# Episode 5416: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5417: Starting Location - X: 2, Y: 7, Z: 2, AOA: 2
# Episode 5418: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5419: Starting Location - X: 1, Y: 2, Z: 0, AOA: 2
# Episode 5420: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5421: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 5422: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 5423: Starting Location - X: 1, Y: 5, Z: 2, AOA: 1
# Episode 5424: Starting Location - X: 3, Y: 2, Z: 1, AOA: 2
# Episode 5425: Starting Location - X: 2, Y: 4, Z: 0, AOA: 2
# Episode 5426: Starting Location - X: 1, Y: 0, Z: 0, AOA: 2
# Episode 5427: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Episode 5428: Starting Location - X: 2, Y: 3, Z: 1, AOA: 2
# Episode 5429: Starting Location - X: 0, Y: 2, Z: 0, AOA: 2
# Episode 5430: Starting Location - X: 0, Y: 1, Z: 2, AOA: 2
# Episode 5431: Starting Location - X: 0, Y: 2, Z: 2, AOA: 2
# Episode 5432: Starting Location - X: 0, Y: 7, Z: 0, AOA: 0
# Episode 5433: Starting Location - X: 0, Y: 3, Z: 1, AOA: 1
# Episode 5434: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5435: Starting Location - X: 3, Y: 3, Z: 2, AOA: 1
# Episode 5436: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 5437: Starting Location - X: 0, Y: 5, Z: 1, AOA: 0
# Episode 5438: Starting Location - X: 1, Y: 0, Z: 2, AOA: 0
# Episode 5439: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5440: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 5441: Starting Location - X: 3, Y: 1, Z: 2, AOA: 2
# Episode 5442: Starting Location - X: 2, Y: 2, Z: 0, AOA: 2
# Episode 5443: Starting Location - X: 2, Y: 7, Z: 2, AOA: 0
# Episode 5444: Starting Location - X: 2, Y: 7, Z: 1, AOA: 0
# Episode 5445: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5446: Starting Location - X: 0, Y: 7, Z: 0, AOA: 1
# Episode 5447: Starting Location - X: 3, Y: 4, Z: 1, AOA: 0
# Episode 5448: Starting Location - X: 1, Y: 5, Z: 0, AOA: 1
# Episode 5449: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 5450: Starting Location - X: 2, Y: 4, Z: 0, AOA: 2
# Episode 5451: Starting Location - X: 3, Y: 2, Z: 2, AOA: 0
# Episode 5452: Starting Location - X: 3, Y: 1, Z: 1, AOA: 0
# Episode 5453: Starting Location - X: 0, Y: 6, Z: 2, AOA: 2
# Episode 5454: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 5455: Starting Location - X: 3, Y: 3, Z: 2, AOA: 2
# Episode 5456: Starting Location - X: 0, Y: 7, Z: 2, AOA: 2
# Episode 5457: Starting Location - X: 1, Y: 5, Z: 1, AOA: 1
# Episode 5458: Starting Location - X: 3, Y: 5, Z: 2, AOA: 1
# Episode 5459: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 5460: Starting Location - X: 2, Y: 6, Z: 2, AOA: 1
# Episode 5461: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 5462: Starting Location - X: 2, Y: 3, Z: 1, AOA: 2
# Episode 5463: Starting Location - X: 3, Y: 5, Z: 1, AOA: 1
# Episode 5464: Starting Location - X: 1, Y: 3, Z: 1, AOA: 1
# Episode 5465: Starting Location - X: 2, Y: 4, Z: 1, AOA: 1
# Episode 5466: Starting Location - X: 0, Y: 6, Z: 1, AOA: 2
# Episode 5467: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5468: Starting Location - X: 2, Y: 0, Z: 0, AOA: 2
# Episode 5469: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 5470: Starting Location - X: 3, Y: 0, Z: 1, AOA: 1
# Episode 5471: Starting Location - X: 0, Y: 3, Z: 0, AOA: 0
# Episode 5472: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 5473: Starting Location - X: 1, Y: 7, Z: 1, AOA: 0
# Episode 5474: Starting Location - X: 3, Y: 0, Z: 2, AOA: 1
# Episode 5475: Starting Location - X: 3, Y: 0, Z: 2, AOA: 0
# Episode 5476: Starting Location - X: 1, Y: 2, Z: 2, AOA: 1
# Episode 5477: Starting Location - X: 1, Y: 4, Z: 2, AOA: 1
# Episode 5478: Starting Location - X: 3, Y: 7, Z: 1, AOA: 0
# Episode 5479: Starting Location - X: 2, Y: 3, Z: 2, AOA: 0
# Episode 5480: Starting Location - X: 2, Y: 2, Z: 1, AOA: 2
# Episode 5481: Starting Location - X: 2, Y: 4, Z: 2, AOA: 2
# Episode 5482: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 5483: Starting Location - X: 3, Y: 7, Z: 2, AOA: 1
# Episode 5484: Starting Location - X: 2, Y: 6, Z: 0, AOA: 1
# Episode 5485: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5486: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 5487: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 5488: Starting Location - X: 2, Y: 2, Z: 0, AOA: 1
# Episode 5489: Starting Location - X: 0, Y: 5, Z: 1, AOA: 0
# Episode 5490: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5491: Starting Location - X: 0, Y: 6, Z: 1, AOA: 0
# Episode 5492: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5493: Starting Location - X: 1, Y: 4, Z: 0, AOA: 1
# Episode 5494: Starting Location - X: 0, Y: 5, Z: 2, AOA: 0
# Episode 5495: Starting Location - X: 0, Y: 2, Z: 1, AOA: 1
# Episode 5496: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 5497: Starting Location - X: 1, Y: 4, Z: 2, AOA: 2
# Episode 5498: Starting Location - X: 1, Y: 4, Z: 0, AOA: 1
# Episode 5499: Starting Location - X: 2, Y: 4, Z: 0, AOA: 0
# Episode 5500: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5501: Starting Location - X: 2, Y: 7, Z: 2, AOA: 1
# Episode 5502: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 5503: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 5504: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5505: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 5506: Starting Location - X: 1, Y: 3, Z: 0, AOA: 0
# Episode 5507: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5508: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5509: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 5510: Starting Location - X: 1, Y: 1, Z: 2, AOA: 2
# Episode 5511: Starting Location - X: 0, Y: 4, Z: 0, AOA: 2
# Episode 5512: Starting Location - X: 2, Y: 3, Z: 1, AOA: 2
# Episode 5513: Starting Location - X: 3, Y: 3, Z: 2, AOA: 0
# Episode 5514: Starting Location - X: 3, Y: 0, Z: 2, AOA: 2
# Episode 5515: Starting Location - X: 3, Y: 6, Z: 1, AOA: 1
# Episode 5516: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5517: Starting Location - X: 0, Y: 7, Z: 0, AOA: 2
# Episode 5518: Starting Location - X: 2, Y: 5, Z: 2, AOA: 2
# Episode 5519: Starting Location - X: 0, Y: 1, Z: 1, AOA: 0
# Episode 5520: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 5521: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 5522: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5523: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5524: Starting Location - X: 1, Y: 6, Z: 0, AOA: 1
# Episode 5525: Starting Location - X: 1, Y: 4, Z: 2, AOA: 1
# Episode 5526: Starting Location - X: 2, Y: 7, Z: 0, AOA: 2
# Episode 5527: Starting Location - X: 1, Y: 0, Z: 0, AOA: 1
# Episode 5528: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 5529: Starting Location - X: 2, Y: 4, Z: 0, AOA: 1
# Episode 5530: Starting Location - X: 3, Y: 6, Z: 1, AOA: 1
# Episode 5531: Starting Location - X: 0, Y: 2, Z: 0, AOA: 0
# Episode 5532: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5533: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 5534: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5535: Starting Location - X: 1, Y: 7, Z: 2, AOA: 0
# Episode 5536: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 5537: Starting Location - X: 0, Y: 1, Z: 1, AOA: 1
# Episode 5538: Starting Location - X: 3, Y: 1, Z: 1, AOA: 0
# Episode 5539: Starting Location - X: 0, Y: 3, Z: 1, AOA: 0
# Episode 5540: Starting Location - X: 3, Y: 5, Z: 2, AOA: 1
# Episode 5541: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5542: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5543: Starting Location - X: 2, Y: 1, Z: 0, AOA: 0
# Episode 5544: Starting Location - X: 2, Y: 4, Z: 1, AOA: 0
# Episode 5545: Starting Location - X: 1, Y: 6, Z: 0, AOA: 0
# Episode 5546: Starting Location - X: 0, Y: 7, Z: 0, AOA: 1
# Episode 5547: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 5548: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 5549: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 5550: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 5551: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5552: Starting Location - X: 3, Y: 2, Z: 1, AOA: 2
# Episode 5553: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5554: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 5555: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 5556: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5557: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 5558: Starting Location - X: 0, Y: 7, Z: 0, AOA: 2
# Episode 5559: Starting Location - X: 0, Y: 3, Z: 1, AOA: 1
# Episode 5560: Starting Location - X: 0, Y: 3, Z: 2, AOA: 2
# Episode 5561: Starting Location - X: 2, Y: 6, Z: 2, AOA: 0
# Episode 5562: Starting Location - X: 1, Y: 0, Z: 0, AOA: 1
# Episode 5563: Starting Location - X: 2, Y: 2, Z: 0, AOA: 1
# Episode 5564: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 5565: Starting Location - X: 3, Y: 6, Z: 2, AOA: 2
# Episode 5566: Starting Location - X: 2, Y: 6, Z: 2, AOA: 1
# Episode 5567: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5568: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 5569: Starting Location - X: 0, Y: 6, Z: 2, AOA: 2
# Episode 5570: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 5571: Starting Location - X: 1, Y: 1, Z: 1, AOA: 0
# Episode 5572: Starting Location - X: 2, Y: 2, Z: 1, AOA: 0
# Episode 5573: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 5574: Starting Location - X: 3, Y: 5, Z: 1, AOA: 1
# Episode 5575: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 5576: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5577: Starting Location - X: 1, Y: 5, Z: 2, AOA: 1
# Episode 5578: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 5579: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 5580: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 5581: Starting Location - X: 0, Y: 0, Z: 2, AOA: 2
# Episode 5582: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5583: Starting Location - X: 3, Y: 3, Z: 2, AOA: 0
# Episode 5584: Starting Location - X: 2, Y: 1, Z: 1, AOA: 2
# Episode 5585: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 5586: Starting Location - X: 0, Y: 2, Z: 0, AOA: 1
# Episode 5587: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 5588: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5589: Starting Location - X: 2, Y: 3, Z: 2, AOA: 2
# Episode 5590: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 5591: Starting Location - X: 0, Y: 0, Z: 1, AOA: 1
# Episode 5592: Starting Location - X: 1, Y: 5, Z: 2, AOA: 0
# Episode 5593: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 5594: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5595: Starting Location - X: 2, Y: 2, Z: 0, AOA: 1
# Episode 5596: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5597: Starting Location - X: 3, Y: 7, Z: 0, AOA: 0
# Episode 5598: Starting Location - X: 0, Y: 0, Z: 2, AOA: 0
# Episode 5599: Starting Location - X: 0, Y: 3, Z: 2, AOA: 2
# Episode 5600: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5601: Starting Location - X: 1, Y: 5, Z: 1, AOA: 1
# Episode 5602: Starting Location - X: 1, Y: 3, Z: 0, AOA: 0
# Episode 5603: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 5604: Starting Location - X: 1, Y: 1, Z: 1, AOA: 0
# Episode 5605: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 5606: Starting Location - X: 3, Y: 5, Z: 1, AOA: 0
# Episode 5607: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 5608: Starting Location - X: 3, Y: 4, Z: 0, AOA: 1
# Episode 5609: Starting Location - X: 3, Y: 6, Z: 0, AOA: 0
# Episode 5610: Starting Location - X: 3, Y: 7, Z: 1, AOA: 2
# Episode 5611: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 5612: Starting Location - X: 2, Y: 1, Z: 0, AOA: 2
# Episode 5613: Starting Location - X: 2, Y: 6, Z: 2, AOA: 1
# Episode 5614: Starting Location - X: 2, Y: 1, Z: 2, AOA: 0
# Episode 5615: Starting Location - X: 1, Y: 5, Z: 2, AOA: 2
# Episode 5616: Starting Location - X: 2, Y: 6, Z: 2, AOA: 2
# Episode 5617: Starting Location - X: 3, Y: 1, Z: 2, AOA: 0
# Episode 5618: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 5619: Starting Location - X: 0, Y: 1, Z: 1, AOA: 1
# Episode 5620: Starting Location - X: 3, Y: 3, Z: 0, AOA: 1
# Episode 5621: Starting Location - X: 0, Y: 2, Z: 1, AOA: 1
# Episode 5622: Starting Location - X: 3, Y: 7, Z: 0, AOA: 0
# Episode 5623: Starting Location - X: 1, Y: 6, Z: 2, AOA: 1
# Episode 5624: Starting Location - X: 1, Y: 4, Z: 2, AOA: 0
# Episode 5625: Starting Location - X: 2, Y: 6, Z: 0, AOA: 2
# Episode 5626: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 5627: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5628: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 5629: Starting Location - X: 2, Y: 6, Z: 1, AOA: 0
# Episode 5630: Starting Location - X: 0, Y: 4, Z: 0, AOA: 2
# Episode 5631: Starting Location - X: 3, Y: 6, Z: 0, AOA: 0
# Episode 5632: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5633: Starting Location - X: 0, Y: 6, Z: 1, AOA: 1
# Episode 5634: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 5635: Starting Location - X: 3, Y: 2, Z: 1, AOA: 0
# Episode 5636: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5637: Starting Location - X: 2, Y: 1, Z: 1, AOA: 2
# Episode 5638: Starting Location - X: 0, Y: 3, Z: 2, AOA: 1
# Episode 5639: Starting Location - X: 3, Y: 2, Z: 0, AOA: 2
# Episode 5640: Starting Location - X: 0, Y: 5, Z: 2, AOA: 2
# Episode 5641: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 5642: Starting Location - X: 0, Y: 6, Z: 1, AOA: 0
# Episode 5643: Starting Location - X: 1, Y: 7, Z: 1, AOA: 0
# Episode 5644: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 5645: Starting Location - X: 0, Y: 3, Z: 1, AOA: 0
# Episode 5646: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 5647: Starting Location - X: 3, Y: 6, Z: 1, AOA: 1
# Episode 5648: Starting Location - X: 1, Y: 7, Z: 0, AOA: 2
# Episode 5649: Starting Location - X: 2, Y: 4, Z: 1, AOA: 0
# Episode 5650: Starting Location - X: 1, Y: 2, Z: 2, AOA: 0
# Episode 5651: Starting Location - X: 1, Y: 6, Z: 1, AOA: 1
# Episode 5652: Starting Location - X: 3, Y: 0, Z: 1, AOA: 1
# Episode 5653: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 5654: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 5655: Starting Location - X: 3, Y: 4, Z: 0, AOA: 1
# Episode 5656: Starting Location - X: 2, Y: 7, Z: 1, AOA: 0
# Episode 5657: Starting Location - X: 0, Y: 7, Z: 2, AOA: 0
# Episode 5658: Starting Location - X: 0, Y: 1, Z: 0, AOA: 0
# Episode 5659: Starting Location - X: 2, Y: 7, Z: 0, AOA: 0
# Episode 5660: Starting Location - X: 1, Y: 0, Z: 0, AOA: 2
# Episode 5661: Starting Location - X: 3, Y: 3, Z: 1, AOA: 2
# Episode 5662: Starting Location - X: 3, Y: 2, Z: 0, AOA: 0
# Episode 5663: Starting Location - X: 3, Y: 2, Z: 1, AOA: 0
# Episode 5664: Starting Location - X: 2, Y: 7, Z: 1, AOA: 2
# Episode 5665: Starting Location - X: 2, Y: 1, Z: 2, AOA: 2
# Episode 5666: Starting Location - X: 1, Y: 2, Z: 1, AOA: 0
# Episode 5667: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 5668: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Episode 5669: Starting Location - X: 0, Y: 5, Z: 2, AOA: 1
# Episode 5670: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 5671: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 5672: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 5673: Starting Location - X: 1, Y: 7, Z: 1, AOA: 2
# Episode 5674: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5675: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5676: Starting Location - X: 1, Y: 3, Z: 2, AOA: 1
# Episode 5677: Starting Location - X: 0, Y: 0, Z: 2, AOA: 0
# Episode 5678: Starting Location - X: 1, Y: 4, Z: 1, AOA: 0
# Episode 5679: Starting Location - X: 3, Y: 2, Z: 1, AOA: 1
# Episode 5680: Starting Location - X: 3, Y: 2, Z: 0, AOA: 1
# Episode 5681: Starting Location - X: 0, Y: 3, Z: 0, AOA: 2
# Episode 5682: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5683: Starting Location - X: 3, Y: 7, Z: 2, AOA: 1
# Episode 5684: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5685: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 5686: Starting Location - X: 0, Y: 3, Z: 1, AOA: 1
# Episode 5687: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 5688: Starting Location - X: 2, Y: 7, Z: 2, AOA: 1
# Episode 5689: Starting Location - X: 3, Y: 6, Z: 0, AOA: 2
# Episode 5690: Starting Location - X: 2, Y: 4, Z: 2, AOA: 2
# Episode 5691: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 5692: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 5693: Starting Location - X: 0, Y: 0, Z: 1, AOA: 0
# Episode 5694: Starting Location - X: 0, Y: 6, Z: 0, AOA: 0
# Episode 5695: Starting Location - X: 3, Y: 2, Z: 1, AOA: 0
# Episode 5696: Starting Location - X: 0, Y: 7, Z: 0, AOA: 2
# Episode 5697: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5698: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 5699: Starting Location - X: 0, Y: 3, Z: 2, AOA: 1
# Episode 5700: Starting Location - X: 1, Y: 4, Z: 2, AOA: 1
# Episode 5701: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 5702: Starting Location - X: 0, Y: 5, Z: 0, AOA: 1
# Episode 5703: Starting Location - X: 3, Y: 0, Z: 1, AOA: 2
# Episode 5704: Starting Location - X: 2, Y: 0, Z: 1, AOA: 2
# Episode 5705: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 5706: Starting Location - X: 3, Y: 1, Z: 2, AOA: 0
# Episode 5707: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5708: Starting Location - X: 0, Y: 7, Z: 2, AOA: 2
# Episode 5709: Starting Location - X: 0, Y: 0, Z: 1, AOA: 2
# Episode 5710: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 5711: Starting Location - X: 2, Y: 1, Z: 0, AOA: 2
# Episode 5712: Starting Location - X: 0, Y: 7, Z: 0, AOA: 2
# Episode 5713: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 5714: Starting Location - X: 3, Y: 6, Z: 2, AOA: 0
# Episode 5715: Starting Location - X: 2, Y: 5, Z: 2, AOA: 0
# Episode 5716: Starting Location - X: 0, Y: 4, Z: 1, AOA: 2
# Episode 5717: Starting Location - X: 2, Y: 0, Z: 2, AOA: 0
# Episode 5718: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 5719: Starting Location - X: 1, Y: 5, Z: 2, AOA: 2
# Episode 5720: Starting Location - X: 2, Y: 5, Z: 1, AOA: 2
# Episode 5721: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 5722: Starting Location - X: 2, Y: 6, Z: 1, AOA: 2
# Episode 5723: Starting Location - X: 0, Y: 0, Z: 0, AOA: 1
# Episode 5724: Starting Location - X: 0, Y: 7, Z: 2, AOA: 1
# Episode 5725: Starting Location - X: 2, Y: 7, Z: 1, AOA: 0
# Episode 5726: Starting Location - X: 0, Y: 1, Z: 0, AOA: 0
# Episode 5727: Starting Location - X: 1, Y: 3, Z: 1, AOA: 1
# Episode 5728: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5729: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 5730: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 5731: Starting Location - X: 1, Y: 5, Z: 0, AOA: 0
# Episode 5732: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 5733: Starting Location - X: 1, Y: 2, Z: 2, AOA: 0
# Episode 5734: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 5735: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 5736: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 5737: Starting Location - X: 3, Y: 5, Z: 0, AOA: 1
# Episode 5738: Starting Location - X: 1, Y: 3, Z: 2, AOA: 2
# Episode 5739: Starting Location - X: 2, Y: 4, Z: 0, AOA: 0
# Episode 5740: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 5741: Starting Location - X: 2, Y: 4, Z: 1, AOA: 0
# Episode 5742: Starting Location - X: 0, Y: 7, Z: 2, AOA: 0
# Episode 5743: Starting Location - X: 1, Y: 2, Z: 0, AOA: 0
# Episode 5744: Starting Location - X: 2, Y: 1, Z: 2, AOA: 1
# Episode 5745: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 5746: Starting Location - X: 0, Y: 4, Z: 0, AOA: 0
# Episode 5747: Starting Location - X: 3, Y: 7, Z: 2, AOA: 0
# Episode 5748: Starting Location - X: 0, Y: 3, Z: 2, AOA: 2
# Episode 5749: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 5750: Starting Location - X: 3, Y: 3, Z: 0, AOA: 0
# Episode 5751: Starting Location - X: 0, Y: 0, Z: 0, AOA: 2
# Episode 5752: Starting Location - X: 3, Y: 2, Z: 2, AOA: 2
# Episode 5753: Starting Location - X: 3, Y: 2, Z: 2, AOA: 0
# Episode 5754: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 5755: Starting Location - X: 0, Y: 2, Z: 2, AOA: 2
# Episode 5756: Starting Location - X: 2, Y: 2, Z: 2, AOA: 2
# Episode 5757: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 5758: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 5759: Starting Location - X: 0, Y: 0, Z: 0, AOA: 0
# Episode 5760: Starting Location - X: 0, Y: 2, Z: 2, AOA: 1
# Episode 5761: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 5762: Starting Location - X: 3, Y: 3, Z: 0, AOA: 2
# Episode 5763: Starting Location - X: 1, Y: 3, Z: 2, AOA: 1
# Episode 5764: Starting Location - X: 3, Y: 7, Z: 0, AOA: 0
# Episode 5765: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 5766: Starting Location - X: 2, Y: 4, Z: 0, AOA: 2
# Episode 5767: Starting Location - X: 2, Y: 3, Z: 0, AOA: 2
# Episode 5768: Starting Location - X: 0, Y: 3, Z: 1, AOA: 1
# Episode 5769: Starting Location - X: 3, Y: 6, Z: 1, AOA: 1
# Episode 5770: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 5771: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 5772: Starting Location - X: 2, Y: 0, Z: 0, AOA: 2
# Episode 5773: Starting Location - X: 1, Y: 0, Z: 0, AOA: 0
# Episode 5774: Starting Location - X: 3, Y: 1, Z: 2, AOA: 2
# Episode 5775: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 5776: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 5777: Starting Location - X: 3, Y: 2, Z: 2, AOA: 0
# Episode 5778: Starting Location - X: 1, Y: 4, Z: 1, AOA: 2
# Episode 5779: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5780: Starting Location - X: 1, Y: 3, Z: 2, AOA: 1
# Episode 5781: Starting Location - X: 0, Y: 0, Z: 2, AOA: 2
# Episode 5782: Starting Location - X: 3, Y: 1, Z: 2, AOA: 2
# Episode 5783: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5784: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 5785: Starting Location - X: 1, Y: 3, Z: 1, AOA: 2
# Episode 5786: Starting Location - X: 1, Y: 0, Z: 0, AOA: 0
# Episode 5787: Starting Location - X: 0, Y: 1, Z: 2, AOA: 1
# Episode 5788: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 5789: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5790: Starting Location - X: 2, Y: 0, Z: 0, AOA: 1
# Episode 5791: Starting Location - X: 3, Y: 4, Z: 0, AOA: 1
# Episode 5792: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 5793: Starting Location - X: 0, Y: 0, Z: 1, AOA: 0
# Episode 5794: Starting Location - X: 0, Y: 3, Z: 1, AOA: 0
# Episode 5795: Starting Location - X: 0, Y: 7, Z: 1, AOA: 1
# Episode 5796: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 5797: Starting Location - X: 3, Y: 1, Z: 1, AOA: 2
# Episode 5798: Starting Location - X: 0, Y: 7, Z: 2, AOA: 2
# Episode 5799: Starting Location - X: 2, Y: 4, Z: 2, AOA: 0
# Episode 5800: Starting Location - X: 3, Y: 2, Z: 2, AOA: 0
# Episode 5801: Starting Location - X: 2, Y: 1, Z: 1, AOA: 0
# Episode 5802: Starting Location - X: 2, Y: 5, Z: 2, AOA: 2
# Episode 5803: Starting Location - X: 3, Y: 4, Z: 0, AOA: 0
# Episode 5804: Starting Location - X: 1, Y: 3, Z: 1, AOA: 1
# Episode 5805: Starting Location - X: 0, Y: 0, Z: 0, AOA: 0
# Episode 5806: Starting Location - X: 2, Y: 0, Z: 1, AOA: 2
# Episode 5807: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 5808: Starting Location - X: 2, Y: 4, Z: 0, AOA: 1
# Episode 5809: Starting Location - X: 2, Y: 4, Z: 2, AOA: 2
# Episode 5810: Starting Location - X: 3, Y: 2, Z: 1, AOA: 2
# Episode 5811: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 5812: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 5813: Starting Location - X: 2, Y: 7, Z: 2, AOA: 0
# Episode 5814: Starting Location - X: 3, Y: 2, Z: 0, AOA: 1
# Episode 5815: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 5816: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 5817: Starting Location - X: 3, Y: 5, Z: 0, AOA: 2
# Episode 5818: Starting Location - X: 2, Y: 2, Z: 0, AOA: 2
# Episode 5819: Starting Location - X: 2, Y: 2, Z: 1, AOA: 0
# ...
# Episode 9732: Starting Location - X: 0, Y: 0, Z: 2, AOA: 1
# Episode 9733: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 9734: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 9735: Starting Location - X: 3, Y: 1, Z: 0, AOA: 2
# Episode 9736: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 9737: Starting Location - X: 1, Y: 1, Z: 0, AOA: 2
# Episode 9738: Starting Location - X: 3, Y: 0, Z: 2, AOA: 2
# Episode 9739: Starting Location - X: 1, Y: 7, Z: 0, AOA: 0
# Episode 9740: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 9741: Starting Location - X: 3, Y: 7, Z: 1, AOA: 1
# Episode 9742: Starting Location - X: 1, Y: 1, Z: 2, AOA: 2
# Episode 9743: Starting Location - X: 3, Y: 1, Z: 1, AOA: 0
# Episode 9744: Starting Location - X: 3, Y: 4, Z: 0, AOA: 0
# Episode 9745: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 9746: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 9747: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 9748: Starting Location - X: 1, Y: 4, Z: 1, AOA: 2
# Episode 9749: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 9750: Starting Location - X: 1, Y: 2, Z: 1, AOA: 0
# Episode 9751: Starting Location - X: 0, Y: 5, Z: 0, AOA: 1
# Episode 9752: Starting Location - X: 0, Y: 6, Z: 0, AOA: 1
# Episode 9753: Starting Location - X: 3, Y: 3, Z: 0, AOA: 1
# Episode 9754: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 9755: Starting Location - X: 3, Y: 4, Z: 2, AOA: 0
# Episode 9756: Starting Location - X: 2, Y: 0, Z: 0, AOA: 0
# Episode 9757: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 9758: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 9759: Starting Location - X: 1, Y: 7, Z: 1, AOA: 2
# Episode 9760: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 9761: Starting Location - X: 1, Y: 1, Z: 2, AOA: 1
# Episode 9762: Starting Location - X: 2, Y: 4, Z: 1, AOA: 1
# Episode 9763: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 9764: Starting Location - X: 1, Y: 0, Z: 2, AOA: 0
# Episode 9765: Starting Location - X: 3, Y: 0, Z: 2, AOA: 2
# Episode 9766: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 9767: Starting Location - X: 1, Y: 0, Z: 1, AOA: 0
# Episode 9768: Starting Location - X: 3, Y: 4, Z: 1, AOA: 0
# Episode 9769: Starting Location - X: 1, Y: 7, Z: 1, AOA: 2
# Episode 9770: Starting Location - X: 2, Y: 3, Z: 0, AOA: 0
# Episode 9771: Starting Location - X: 1, Y: 5, Z: 2, AOA: 0
# Episode 9772: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 9773: Starting Location - X: 1, Y: 0, Z: 2, AOA: 1
# Episode 9774: Starting Location - X: 2, Y: 0, Z: 2, AOA: 0
# Episode 9775: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 9776: Starting Location - X: 2, Y: 3, Z: 2, AOA: 2
# Episode 9777: Starting Location - X: 0, Y: 5, Z: 0, AOA: 2
# Episode 9778: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 9779: Starting Location - X: 3, Y: 5, Z: 0, AOA: 0
# Episode 9780: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 9781: Starting Location - X: 1, Y: 0, Z: 0, AOA: 2
# Episode 9782: Starting Location - X: 2, Y: 7, Z: 1, AOA: 2
# Episode 9783: Starting Location - X: 3, Y: 4, Z: 0, AOA: 1
# Episode 9784: Starting Location - X: 1, Y: 3, Z: 2, AOA: 1
# Episode 9785: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 9786: Starting Location - X: 3, Y: 0, Z: 1, AOA: 2
# Episode 9787: Starting Location - X: 0, Y: 5, Z: 1, AOA: 2
# Episode 9788: Starting Location - X: 0, Y: 3, Z: 0, AOA: 1
# Episode 9789: Starting Location - X: 3, Y: 5, Z: 0, AOA: 0
# Episode 9790: Starting Location - X: 1, Y: 2, Z: 2, AOA: 1
# Episode 9791: Starting Location - X: 0, Y: 3, Z: 0, AOA: 0
# Episode 9792: Starting Location - X: 1, Y: 7, Z: 1, AOA: 2
# Episode 9793: Starting Location - X: 2, Y: 4, Z: 2, AOA: 0
# Episode 9794: Starting Location - X: 2, Y: 7, Z: 2, AOA: 2
# Episode 9795: Starting Location - X: 3, Y: 6, Z: 2, AOA: 1
# Episode 9796: Starting Location - X: 1, Y: 0, Z: 2, AOA: 1
# Episode 9797: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 9798: Starting Location - X: 3, Y: 2, Z: 0, AOA: 0
# Episode 9799: Starting Location - X: 2, Y: 2, Z: 0, AOA: 2
# Episode 9800: Starting Location - X: 2, Y: 3, Z: 2, AOA: 0
# Episode 9801: Starting Location - X: 1, Y: 5, Z: 0, AOA: 1
# Episode 9802: Starting Location - X: 1, Y: 6, Z: 0, AOA: 2
# Episode 9803: Starting Location - X: 3, Y: 1, Z: 1, AOA: 0
# Episode 9804: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 9805: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 9806: Starting Location - X: 2, Y: 7, Z: 0, AOA: 2
# Episode 9807: Starting Location - X: 0, Y: 7, Z: 0, AOA: 0
# Episode 9808: Starting Location - X: 2, Y: 7, Z: 2, AOA: 0
# Episode 9809: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 9810: Starting Location - X: 2, Y: 7, Z: 0, AOA: 0
# Episode 9811: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 9812: Starting Location - X: 1, Y: 3, Z: 2, AOA: 2
# Episode 9813: Starting Location - X: 0, Y: 0, Z: 1, AOA: 0
# Episode 9814: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 9815: Starting Location - X: 2, Y: 3, Z: 1, AOA: 0
# Episode 9816: Starting Location - X: 1, Y: 2, Z: 1, AOA: 0
# Episode 9817: Starting Location - X: 1, Y: 4, Z: 0, AOA: 2
# Episode 9818: Starting Location - X: 1, Y: 5, Z: 0, AOA: 2
# Episode 9819: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Episode 9820: Starting Location - X: 1, Y: 4, Z: 2, AOA: 0
# Episode 9821: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 9822: Starting Location - X: 2, Y: 7, Z: 0, AOA: 2
# Episode 9823: Starting Location - X: 3, Y: 3, Z: 0, AOA: 1
# Episode 9824: Starting Location - X: 3, Y: 3, Z: 2, AOA: 1
# Episode 9825: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 9826: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 9827: Starting Location - X: 0, Y: 0, Z: 1, AOA: 0
# Episode 9828: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 9829: Starting Location - X: 3, Y: 3, Z: 0, AOA: 1
# Episode 9830: Starting Location - X: 0, Y: 7, Z: 2, AOA: 0
# Episode 9831: Starting Location - X: 0, Y: 6, Z: 1, AOA: 0
# Episode 9832: Starting Location - X: 2, Y: 4, Z: 2, AOA: 0
# Episode 9833: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 9834: Starting Location - X: 1, Y: 7, Z: 2, AOA: 0
# Episode 9835: Starting Location - X: 1, Y: 6, Z: 0, AOA: 0
# Episode 9836: Starting Location - X: 3, Y: 5, Z: 1, AOA: 0
# Episode 9837: Starting Location - X: 1, Y: 1, Z: 2, AOA: 0
# Episode 9838: Starting Location - X: 3, Y: 5, Z: 2, AOA: 0
# Episode 9839: Starting Location - X: 1, Y: 0, Z: 1, AOA: 1
# Episode 9840: Starting Location - X: 2, Y: 0, Z: 0, AOA: 0
# Episode 9841: Starting Location - X: 0, Y: 0, Z: 1, AOA: 1
# Episode 9842: Starting Location - X: 1, Y: 2, Z: 2, AOA: 0
# Episode 9843: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 9844: Starting Location - X: 3, Y: 5, Z: 1, AOA: 1
# Episode 9845: Starting Location - X: 0, Y: 0, Z: 2, AOA: 2
# Episode 9846: Starting Location - X: 2, Y: 7, Z: 2, AOA: 1
# Episode 9847: Starting Location - X: 1, Y: 2, Z: 0, AOA: 1
# Episode 9848: Starting Location - X: 1, Y: 1, Z: 2, AOA: 0
# Episode 9849: Starting Location - X: 0, Y: 6, Z: 0, AOA: 1
# Episode 9850: Starting Location - X: 1, Y: 5, Z: 0, AOA: 0
# Episode 9851: Starting Location - X: 1, Y: 5, Z: 0, AOA: 1
# Episode 9852: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 9853: Starting Location - X: 1, Y: 3, Z: 0, AOA: 1
# Episode 9854: Starting Location - X: 0, Y: 5, Z: 0, AOA: 1
# Episode 9855: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 9856: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 9857: Starting Location - X: 0, Y: 6, Z: 1, AOA: 2
# Episode 9858: Starting Location - X: 2, Y: 4, Z: 0, AOA: 0
# Episode 9859: Starting Location - X: 0, Y: 1, Z: 2, AOA: 0
# Episode 9860: Starting Location - X: 3, Y: 2, Z: 2, AOA: 1
# Episode 9861: Starting Location - X: 0, Y: 4, Z: 1, AOA: 0
# Episode 9862: Starting Location - X: 3, Y: 5, Z: 1, AOA: 0
# Episode 9863: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 9864: Starting Location - X: 1, Y: 5, Z: 2, AOA: 1
# Episode 9865: Starting Location - X: 2, Y: 3, Z: 1, AOA: 1
# Episode 9866: Starting Location - X: 3, Y: 0, Z: 2, AOA: 2
# Episode 9867: Starting Location - X: 0, Y: 1, Z: 0, AOA: 0
# Episode 9868: Starting Location - X: 3, Y: 3, Z: 0, AOA: 0
# Episode 9869: Starting Location - X: 3, Y: 4, Z: 2, AOA: 2
# Episode 9870: Starting Location - X: 3, Y: 5, Z: 2, AOA: 1
# Episode 9871: Starting Location - X: 3, Y: 7, Z: 0, AOA: 1
# Episode 9872: Starting Location - X: 2, Y: 6, Z: 1, AOA: 1
# Episode 9873: Starting Location - X: 1, Y: 0, Z: 2, AOA: 2
# Episode 9874: Starting Location - X: 1, Y: 2, Z: 0, AOA: 2
# Episode 9875: Starting Location - X: 2, Y: 0, Z: 1, AOA: 2
# Episode 9876: Starting Location - X: 2, Y: 0, Z: 2, AOA: 1
# Episode 9877: Starting Location - X: 1, Y: 2, Z: 0, AOA: 2
# Episode 9878: Starting Location - X: 1, Y: 1, Z: 1, AOA: 0
# Episode 9879: Starting Location - X: 3, Y: 4, Z: 0, AOA: 2
# Episode 9880: Starting Location - X: 1, Y: 6, Z: 0, AOA: 1
# Episode 9881: Starting Location - X: 2, Y: 6, Z: 0, AOA: 0
# Episode 9882: Starting Location - X: 0, Y: 2, Z: 1, AOA: 1
# Episode 9883: Starting Location - X: 3, Y: 5, Z: 2, AOA: 2
# Episode 9884: Starting Location - X: 2, Y: 7, Z: 2, AOA: 2
# Episode 9885: Starting Location - X: 3, Y: 5, Z: 1, AOA: 0
# Episode 9886: Starting Location - X: 3, Y: 5, Z: 0, AOA: 0
# Episode 9887: Starting Location - X: 0, Y: 4, Z: 2, AOA: 1
# Episode 9888: Starting Location - X: 0, Y: 7, Z: 2, AOA: 1
# Episode 9889: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 9890: Starting Location - X: 0, Y: 7, Z: 1, AOA: 2
# Episode 9891: Starting Location - X: 3, Y: 5, Z: 2, AOA: 0
# Episode 9892: Starting Location - X: 0, Y: 3, Z: 2, AOA: 2
# Episode 9893: Starting Location - X: 1, Y: 0, Z: 0, AOA: 2
# Episode 9894: Starting Location - X: 2, Y: 7, Z: 0, AOA: 0
# Episode 9895: Starting Location - X: 2, Y: 4, Z: 2, AOA: 1
# Episode 9896: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 9897: Starting Location - X: 2, Y: 5, Z: 1, AOA: 1
# Episode 9898: Starting Location - X: 1, Y: 3, Z: 1, AOA: 2
# Episode 9899: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 9900: Starting Location - X: 2, Y: 2, Z: 1, AOA: 1
# Episode 9901: Starting Location - X: 2, Y: 0, Z: 1, AOA: 0
# Episode 9902: Starting Location - X: 1, Y: 7, Z: 1, AOA: 1
# Episode 9903: Starting Location - X: 0, Y: 7, Z: 2, AOA: 2
# Episode 9904: Starting Location - X: 0, Y: 4, Z: 0, AOA: 1
# Episode 9905: Starting Location - X: 2, Y: 5, Z: 2, AOA: 1
# Episode 9906: Starting Location - X: 0, Y: 1, Z: 0, AOA: 0
# Episode 9907: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 9908: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 9909: Starting Location - X: 1, Y: 1, Z: 0, AOA: 0
# Episode 9910: Starting Location - X: 3, Y: 6, Z: 0, AOA: 1
# Episode 9911: Starting Location - X: 2, Y: 5, Z: 0, AOA: 2
# Episode 9912: Starting Location - X: 2, Y: 4, Z: 0, AOA: 0
# Episode 9913: Starting Location - X: 2, Y: 7, Z: 1, AOA: 1
# Episode 9914: Starting Location - X: 2, Y: 0, Z: 1, AOA: 1
# Episode 9915: Starting Location - X: 0, Y: 2, Z: 1, AOA: 2
# Episode 9916: Starting Location - X: 2, Y: 0, Z: 2, AOA: 2
# Episode 9917: Starting Location - X: 3, Y: 6, Z: 2, AOA: 2
# Episode 9918: Starting Location - X: 1, Y: 4, Z: 2, AOA: 1
# Episode 9919: Starting Location - X: 3, Y: 0, Z: 2, AOA: 0
# Episode 9920: Starting Location - X: 3, Y: 5, Z: 1, AOA: 2
# Episode 9921: Starting Location - X: 1, Y: 7, Z: 2, AOA: 1
# Episode 9922: Starting Location - X: 2, Y: 4, Z: 1, AOA: 0
# Episode 9923: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 9924: Starting Location - X: 0, Y: 2, Z: 0, AOA: 0
# Episode 9925: Starting Location - X: 0, Y: 4, Z: 1, AOA: 0
# Episode 9926: Starting Location - X: 1, Y: 7, Z: 2, AOA: 2
# Episode 9927: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 9928: Starting Location - X: 3, Y: 3, Z: 1, AOA: 0
# Episode 9929: Starting Location - X: 1, Y: 0, Z: 1, AOA: 1
# Episode 9930: Starting Location - X: 3, Y: 7, Z: 1, AOA: 2
# Episode 9931: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 9932: Starting Location - X: 3, Y: 6, Z: 1, AOA: 0
# Episode 9933: Starting Location - X: 2, Y: 4, Z: 1, AOA: 1
# Episode 9934: Starting Location - X: 1, Y: 3, Z: 1, AOA: 2
# Episode 9935: Starting Location - X: 2, Y: 0, Z: 1, AOA: 2
# Episode 9936: Starting Location - X: 1, Y: 4, Z: 0, AOA: 2
# Episode 9937: Starting Location - X: 1, Y: 2, Z: 0, AOA: 1
# Episode 9938: Starting Location - X: 3, Y: 5, Z: 1, AOA: 1
# Episode 9939: Starting Location - X: 1, Y: 7, Z: 0, AOA: 1
# Episode 9940: Starting Location - X: 0, Y: 7, Z: 2, AOA: 0
# Episode 9941: Starting Location - X: 1, Y: 1, Z: 0, AOA: 1
# Episode 9942: Starting Location - X: 3, Y: 0, Z: 1, AOA: 1
# Episode 9943: Starting Location - X: 0, Y: 6, Z: 1, AOA: 0
# Episode 9944: Starting Location - X: 2, Y: 5, Z: 0, AOA: 1
# Episode 9945: Starting Location - X: 0, Y: 1, Z: 2, AOA: 2
# Episode 9946: Starting Location - X: 2, Y: 1, Z: 0, AOA: 1
# Episode 9947: Starting Location - X: 1, Y: 6, Z: 2, AOA: 1
# Episode 9948: Starting Location - X: 3, Y: 6, Z: 2, AOA: 1
# Episode 9949: Starting Location - X: 2, Y: 2, Z: 0, AOA: 1
# Episode 9950: Starting Location - X: 0, Y: 4, Z: 0, AOA: 0
# Episode 9951: Starting Location - X: 0, Y: 3, Z: 1, AOA: 2
# Episode 9952: Starting Location - X: 1, Y: 2, Z: 1, AOA: 1
# Episode 9953: Starting Location - X: 0, Y: 4, Z: 2, AOA: 0
# Episode 9954: Starting Location - X: 0, Y: 5, Z: 0, AOA: 0
# Episode 9955: Starting Location - X: 0, Y: 4, Z: 1, AOA: 1
# Episode 9956: Starting Location - X: 0, Y: 2, Z: 2, AOA: 0
# Episode 9957: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 9958: Starting Location - X: 3, Y: 1, Z: 0, AOA: 1
# Episode 9959: Starting Location - X: 1, Y: 6, Z: 2, AOA: 2
# Episode 9960: Starting Location - X: 3, Y: 1, Z: 2, AOA: 1
# Episode 9961: Starting Location - X: 1, Y: 3, Z: 0, AOA: 2
# Episode 9962: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 9963: Starting Location - X: 3, Y: 5, Z: 1, AOA: 1
# Episode 9964: Starting Location - X: 3, Y: 4, Z: 0, AOA: 0
# Episode 9965: Starting Location - X: 1, Y: 5, Z: 2, AOA: 1
# Episode 9966: Starting Location - X: 0, Y: 1, Z: 0, AOA: 0
# Episode 9967: Starting Location - X: 3, Y: 1, Z: 1, AOA: 0
# Episode 9968: Starting Location - X: 2, Y: 1, Z: 1, AOA: 1
# Episode 9969: Starting Location - X: 1, Y: 1, Z: 1, AOA: 1
# Episode 9970: Starting Location - X: 0, Y: 1, Z: 1, AOA: 2
# Episode 9971: Starting Location - X: 3, Y: 0, Z: 0, AOA: 2
# Episode 9972: Starting Location - X: 3, Y: 0, Z: 0, AOA: 0
# Episode 9973: Starting Location - X: 3, Y: 1, Z: 1, AOA: 1
# Episode 9974: Starting Location - X: 2, Y: 5, Z: 1, AOA: 0
# Episode 9975: Starting Location - X: 2, Y: 2, Z: 2, AOA: 1
# Episode 9976: Starting Location - X: 3, Y: 0, Z: 1, AOA: 2
# Episode 9977: Starting Location - X: 3, Y: 0, Z: 1, AOA: 0
# Episode 9978: Starting Location - X: 2, Y: 3, Z: 1, AOA: 2
# Episode 9979: Starting Location - X: 1, Y: 2, Z: 1, AOA: 2
# Episode 9980: Starting Location - X: 2, Y: 6, Z: 1, AOA: 2
# Episode 9981: Starting Location - X: 1, Y: 3, Z: 0, AOA: 1
# Episode 9982: Starting Location - X: 3, Y: 3, Z: 2, AOA: 2
# Episode 9983: Starting Location - X: 3, Y: 7, Z: 1, AOA: 1
# Episode 9984: Starting Location - X: 1, Y: 5, Z: 1, AOA: 2
# Episode 9985: Starting Location - X: 1, Y: 0, Z: 1, AOA: 2
# Episode 9986: Starting Location - X: 0, Y: 0, Z: 1, AOA: 0
# Episode 9987: Starting Location - X: 0, Y: 0, Z: 2, AOA: 0
# Episode 9988: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 9989: Starting Location - X: 2, Y: 7, Z: 0, AOA: 1
# Episode 9990: Starting Location - X: 0, Y: 6, Z: 1, AOA: 1
# Episode 9991: Starting Location - X: 3, Y: 5, Z: 2, AOA: 2
# Episode 9992: Starting Location - X: 1, Y: 2, Z: 2, AOA: 2
# Episode 9993: Starting Location - X: 3, Y: 4, Z: 0, AOA: 0
# Episode 9994: Starting Location - X: 3, Y: 7, Z: 0, AOA: 2
# Episode 9995: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Episode 9996: Starting Location - X: 1, Y: 3, Z: 1, AOA: 0
# Episode 9997: Starting Location - X: 3, Y: 3, Z: 1, AOA: 1
# Episode 9998: Starting Location - X: 2, Y: 1, Z: 0, AOA: 0
# Episode 9999: Starting Location - X: 2, Y: 2, Z: 2, AOA: 1
# Episode 10000: Starting Location - X: 0, Y: 6, Z: 2, AOA: 0
# Highest L/D Ratio: 9.06201 at Location: (2, 1, 4, 1)
#
# Training Complete

# %%
# Helper function: Testing the policy on new data
def apply_policy(policy, rewards_new, max_steps=100):
    # Choose a starting location for the new data (random or specified)
    x_index, y_index, z_index, aoa_index = get_starting_location()

    total_reward = 0
    max_ld_ratio = float('-inf')  # Initialize to a very low value to find the maximum
    steps = 0
    # Loop until reaching the maximum number of steps
    while steps < max_steps:
        # Choose the best action based on the policy
        action = policy[x_index, y_index, z_index, aoa_index]

        # Transition to the next state using the chosen action
        old_x_index, old_y_index, old_z_index, old_aoa_index = x_index, y_index, z_index, aoa_index
        x_index, y_index, z_index, aoa_index = get_next_location(x_index, y_index, z_index, aoa_index, action)

        # Collect the reward (L/D ratio) from the new state
        reward = rewards_new[z_index, x_index, y_index, aoa_index]
        total_reward += reward

        # Update the maximum L/D ratio if the current reward is higher
        if reward > max_ld_ratio:
            max_ld_ratio = reward

        # Increment the step count
        steps += 1

    # Return the total reward collected, the number of steps taken, and the max L/D ratio found
    return total_reward, steps, max_ld_ratio

# %%
#New data use excel L/D true stats 1 (not 0)
import numpy as np
##Data taken from L/D true stats 0 (not 1)
# Re-initializing the original matrix (3x4x8) and the two additional matrices for different AOAs
# Given data, formatting it into a matrix structure like the example provided for ld_ratios_aoa1_new
ld_ratios_aoa1_new = np.array([
    [
        [-0.449103915, -0.476704828, -0.197835889, 0.485549045, 0.754181376, 0.697325337, 0.707674753, 0.704522477],
        [-1.942295073, -1.087457877, -0.344006028, 0.445383109, 1.27784131, 0.785712036, 0.73605239, 0.629326025],
        [-0.711570416, -0.550548873, 0.072867277, 0.504347759, 0.760418777, 0.732372, 0.721307771, 0.643072318],
        [-0.462149214, -0.062391545, 0.500210224, 0.571818582, 0.718347384, 0.636749984, 0.685264857, 0.632480888]
    ],
    [
        [-0.351557131, -0.365309554, -0.013108486, 0.565348282, 0.609791921, 0.589128265, 0.4835965, 0.502810265],
        [-1.502448431, -0.714586576, 0.081132463, 0.543758225, 1.217006464, 0.739692564, 0.53266645, 0.490037523],
        [-0.773900004, -0.572850942, 0.138414821, 0.476295008, 0.700371423, 0.665684194, 0.527901642, 0.424678049],
        [-0.345265935, -0.5156932, -0.043721715, 0.352461351, 0.506919983, 0.48782122, 0.45818463, 0.408908831]
    ],
    [
        [0.728380074, 0.693093596, 1.978689223, 2.610779422, 2.94155075, 3.009631673, 2.87680253, 2.867997189],
        [-1.506864953, -0.124090095, 1.494815707, 2.942580682, 4.763446717, 3.257724414, 3.064342554, 2.954570791],
        [-0.058551016, 0.526905254, 1.384439154, 2.737848846, 3.472699817, 3.408255482, 3.111604709, 2.907793935],
        [0.761653003, 0.841330889, 1.960720736, 2.68338884, 2.995094553, 3.017492757, 2.979645791, 2.728300039]
    ]
])




# Formatting the provided data for AOA 2 into a similar matrix structure
ld_ratios_aoa2_new = np.array([
    [
        [-0.728902438, -0.687459928, -0.716079276, -0.116394361, 0.290754594, 0.265684526, 0.186290962, 0.235915442],
        [-1.690390073, -1.062964859, -0.343809628, 0.291673873, 1.434050365, 0.49132875, 0.272777704, 0.195975723],
        [-0.602373508, -0.901315073, 0.037482677, 0.358408236, 0.629982837, 0.503994306, 0.338269938, 0.297074474],
        [-0.486084915, -0.3632743, -0.173961456, 0.20456086, 0.49085958, 0.439489301, 0.378782697, 0.281871642]
    ],
    [
        [-0.781882689, -0.752830856, -0.704690719, -0.042418902, 0.283006112, 0.116871816, 0.011689997, 0.023881062],
        [-1.542850311, -0.827942662, -0.152190582, 0.226456743, 1.043213562, 0.25481176, 0.115690214, 0.039885584],
        [-0.811811177, -0.547548312, -0.16369801, 0.187718503, 0.411008929, 0.302150869, 0.068256425, 0.036385521],
        [-0.529119352, -0.425220034, -0.231294456, 0.01334563, 0.150675714, 0.140887635, 0.061624851, -0.028894791]
    ],
    [
        [1.21164152, 1.168660253, 1.202499412, 3.066973411, 4.037391437, 3.76517043, 3.513615773, 3.553893539],
        [-0.099640823, 0.810929893, 2.667934629, 4.054394162, 7.848565063, 4.556453664, 3.456825858, 3.405663696],
        [1.018808435, 1.946533942, 2.504762005, 3.475290686, 4.563951418, 3.99064608, 3.70068588, 3.19518864],
        [2.344989606, 3.450319564, 3.466689719, 3.43399609, 3.460875167, 3.574771244, 3.370572031, 2.988145469]
    ]
])

# Formatting the provided data for AOA 3 into a similar matrix structure
ld_ratios_aoa3_new = np.array([
    [
        [-0.370496607, -0.30425536, -0.191295319, 0.420209856, 0.724103277, -0.524621484, -0.509801836, -0.526324808],
        [-1.338289739, -0.834195263, -0.093501296, -0.841419877, -0.072999874, -0.504434403, -0.558810743, -0.59509547],
        [-0.393411604, -0.496004557, -0.082545632, 0.49061867, -0.488215018, -0.48528805, -0.532432537, -0.555095227],
        [-0.070731815, -0.176015894, 0.220982403, 0.526025749, 0.677067443, -0.513097286, -0.523472487, 0.621450167]
    ],
    [
        [-0.211922228, -0.143062199, 0.014541715, 0.461282639, -0.562129516, -0.551629113, -0.596580334, 0.53955199],
        [-1.053438941, -0.604497122, 0.160199659, -0.789874713, -0.097796013, -0.452737949, -0.57768559, -0.607481508],
        [-0.416588445, -0.382010274, 0.050758166, -0.641302334, -0.506230625, -0.515072581, -0.590788019, -0.626345036],
        [-0.039996216, -0.153987945, 0.089160705, 0.458987589, -0.558654358, 0.600517613, -0.60311788, -0.629717487]
    ],
    [
        [3.132597421, 3.408769911, 3.428038088, 1.189432862, 1.578855024, 1.558425844, 1.558823953, 1.556166112],
        [1.501633535, 2.001823038, 3.396848663, 0.993446593, 2.379573585, 1.703913242, 1.63557189, 2.626581121],
        [2.74768833, 2.908571897, 3.81389174, 1.357878598, 1.635146417, 1.618708741, 5.588516984, 1.34104996],
        [3.7399687, 3.926933468, 4.340883038, 5.14995458, 1.575843881, 1.548489528, 1.575424976, 5.156511936]
    ]
])

# Combining the matrices along a new dimension for AOA
rewards_new = np.stack([ld_ratios_aoa1_new, ld_ratios_aoa2_new, ld_ratios_aoa3_new], axis=3)
max_reward_new = np.max(rewards_new)

# Confirming the shape of the resulting matrix
rewards_new.shape
print(f"Largest Reward: {max_reward_new}")
# Out:
# Largest Reward: 7.848565063

# %%
#new training
total_reward, steps, max_ld_ratio = apply_policy(policy, rewards_new)
print(f"Total Reward Collected: {total_reward}")
print(f"Number of Steps Taken: {steps}")
print(f"Maximum L/D Ratio Encountered: {max_ld_ratio}")
# Out:
# Total Reward Collected: 752.8823828130014
# Number of Steps Taken: 100
# Maximum L/D Ratio Encountered: 7.848565063

# %% [markdown]
# ## Get Shortest Paths
# Now that the AI agent has been fully trained, we can see what it has learned by displaying the shortest path between any location in the warehouse where the robot is allowed to travel and the item packaging area.
#
# ![warehouse map](https://www.danielsoper.com/teaching/img/08-warehouse-map.png)
#
# Run the code cell below to try a few different starting locations!

# %%
#display a few shortest paths
print(get_shortest_path(3, 9)) #starting at row 3, column 9
print(get_shortest_path(5, 0)) #starting at row 5, column 0
print(get_shortest_path(9, 5)) #starting at row 9, column 5

# %% [markdown]
# #### Finally...
# It's great that our robot can automatically take the shortest path from any 'legal' location in the warehouse to the item packaging area. **But what about the opposite scenario?**
#
# Put differently, our robot can currently deliver an item from anywhere in the warehouse ***to*** the packaging area, but after it delivers the item, it will need to travel ***from*** the packaging area to another location in the warehouse to pick up the next item!
#
# Don't worry -- this problem is easily solved simply by ***reversing the order of the shortest path***.
#
# Run the code cell below to see an example:

# %%
#display an example of reversed shortest path
path = get_shortest_path(5, 2) #go to row 5, column 2
path.reverse()
print(path)
